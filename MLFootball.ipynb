# %%
import pandas as pd

# %%
gamelogs = pd.read_csv('nfl_df.csv', index_col=None)

# %%
n_columns_to_keep = 38
gamelogs = gamelogs.iloc[: , :n_columns_to_keep]

# %%
gamelogs = gamelogs.drop(columns=['Unnamed: 3'])

# %%
gamelogs.rename(columns={'Unnamed: 6': 'venue'}, inplace=True)

# %%
gamelogs.rename(columns={'Unnamed: 4': 'W/L'}, inplace=True)

# %%
gamelogs["full_date"] = gamelogs["Date"] + " " + gamelogs["Season"].astype(str)

# %%
gamelogs["full_date"] = pd.to_datetime(gamelogs["full_date"], format="%B %d %Y", errors="coerce")

# %%
gamelogs["Date"] = gamelogs["full_date"]

# %%
gamelogs = gamelogs.drop(columns=["full_date"])

# %%
gamelogs["Date"] = pd.to_datetime(gamelogs["Date"])

# %%
gamelogs["venue_code"] = gamelogs["venue"].astype("category").cat.codes #convert string into category which is converted into nunmbers

# %%
gamelogs["opp_code"] = gamelogs["Opp"].astype("category").cat.codes

# %%
gamelogs["day_code"] = gamelogs["Date"].dt.dayofweek #convert date into day of week

# %%
gamelogs["target"] = (gamelogs["W/L"] == "W").astype("int")

# %%
from sklearn.ensemble import RandomForestClassifier

# %%
rf = RandomForestClassifier(n_estimators=50, min_samples_split=10, random_state=1)

# %%
train = gamelogs[gamelogs["Date"] < '2024-9-8']

# %%
test = gamelogs[gamelogs["Date"] >= '2024-9-8']

# %%
predictors = ["venue_code", "opp_code", "day_code"]

# %%
rf.fit(train[predictors], train["target"])
# Out:
# RandomForestClassifier(min_samples_split=10, n_estimators=50, random_state=1)

# %%
preds = rf.predict(test[predictors])

# %%
from sklearn.metrics import accuracy_score

# %%
accuracy = accuracy_score(test["target"], preds)

# %%
combined = pd.DataFrame(dict(actual=test["target"], prediction=preds))

# %%
pd.crosstab(index=combined["actual"], columns=combined["prediction"])
# Out:
# prediction    0    1
# actual
# 0           139  115
# 1           129  125

# %%
from sklearn.metrics import precision_score

# %%
precision_score(test["target"], preds)
# Out:
# 0.5208333333333334

# %%
grouped_games = gamelogs.groupby("Team")

# %%
group = grouped_games.get_group("CRD")

# %%
def rolling_averages(group, cols, new_cols):
  group = group.sort_values("Date")
  rolling_stats = group[cols].rolling(3, closed='left').mean()
  group[new_cols] = rolling_stats
  group = group.dropna(subset=new_cols)
  return group

# %%
cols = ["Tm", "Opp.1", "Cmp", "Att", "Yds", "Int", "Sk", "Yds.1", "Y/A", "NY/A", "Cmp%", "Rate", "Att.1", "Yds.2", "Y/A.1", "TD.1", "FGM", "FGA", "XPM", "XPA", "Pnt", "Yds.3", "3DConv", "3DAtt", "4DConv", "4DAtt"]
new_cols = [f"{c}_rolling" for c in cols]

# %%
rolling_averages(group, cols, new_cols)
# Out:
#       Season  Week Team  Day       Date W/L   OT venue                   Opp  \
# 1       2021     2  CRD  Sun 2021-09-19   W  NaN   NaN     Minnesota Vikings
# 2       2021     3  CRD  Sun 2021-09-26   W  NaN     @  Jacksonville Jaguars
# 3       2021     4  CRD  Sun 2021-10-03   W  NaN     @      Los Angeles Rams
# 4       2021     5  CRD  Sun 2021-10-10   W  NaN   NaN   San Francisco 49ers
# 5       2021     6  CRD  Sun 2021-10-17   W  NaN     @      Cleveland Browns
# ...      ...   ...  ...  ...        ...  ..  ...   ...                   ...
# 1641    2024    13  CRD  Sun 2024-12-01   L  NaN     @     Minnesota Vikings
# 1642    2024    14  CRD  Sun 2024-12-08   L  NaN   NaN      Seattle Seahawks
# 1643    2024    15  CRD  Sun 2024-12-15   W  NaN   NaN  New England Patriots
# 1644    2024    16  CRD  Sun 2024-12-22   L   OT     @     Carolina Panthers
# 1645    2024    17  CRD  Sat 2024-12-28   L  NaN     @      Los Angeles Rams
#
#       Tm  ...  FGM_rolling  FGA_rolling  XPM_rolling  XPA_rolling  \
# 1     34  ...     2.666667     3.000000     3.000000     3.000000
# 2     31  ...     2.000000     2.333333     4.000000     4.000000
# 3     37  ...     1.333333     2.000000     4.333333     4.333333
# 4     17  ...     2.000000     2.333333     4.000000     4.000000
# 5     37  ...     1.666667     2.333333     3.333333     3.333333
# ...   ..  ...          ...          ...          ...          ...
# 1641  22  ...     1.666667     2.000000     2.333333     2.333333
# 1642  18  ...     2.666667     3.333333     1.666667     1.666667
# 1643  30  ...     2.666667     3.666667     0.666667     0.666667
# 1644  30  ...     3.000000     3.666667     1.666667     1.666667
# 1645   9  ...     2.333333     2.666667     2.333333     2.333333
#
#       Pnt_rolling  Yds.3_rolling  3DConv_rolling  3DAtt_rolling  \
# 1        3.000000     139.666667        7.666667      15.666667
# 2        3.333333     173.000000        6.333333      13.333333
# 3        4.000000     206.000000        3.666667      10.333333
# 4        3.666667     187.333333        4.000000      10.333333
# 5        3.666667     182.000000        4.000000      10.666667
# ...           ...            ...             ...            ...
# 1641     3.666667     179.000000        4.333333      10.666667
# 1642     2.666667     130.666667        4.333333      10.666667
# 1643     3.666667     177.333333        4.000000      12.333333
# 1644     2.333333     106.333333        6.333333      13.333333
# 1645     3.000000     131.666667        6.666667      13.333333
#
#       4DConv_rolling  4DAtt_rolling
# 1           1.000000       1.333333
# 2           0.666667       1.000000
# 3           1.000000       1.000000
# 4           1.000000       1.000000
# 5           0.666667       0.666667
# ...              ...            ...
# 1641        0.333333       1.000000
# 1642        0.333333       1.000000
# 1643        0.333333       1.000000
# 1644        0.333333       0.666667
# 1645        0.666667       0.666667
#
# [65 rows x 67 columns]

# %%
gamelogs_rolling = gamelogs.groupby("Team").apply(lambda x: rolling_averages(x, cols, new_cols))
# Out:
# <ipython-input-82-7c0b44464204>:1: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   gamelogs_rolling = gamelogs.groupby("Team").apply(lambda x: rolling_averages(x, cols, new_cols))

# %%
gamelogs_rolling = gamelogs_rolling.droplevel("Team")

# %%
gamelogs_rolling.index = range(gamelogs_rolling.shape[0])

# %%
predictors += new_cols

# %%
def make_predictions(data, predictors):
    train = data[data["Date"] < '2024-9-8']
    test = data[data["Date"] >= '2024-9-8']
    rf.fit(train[predictors], train["target"])
    preds = rf.predict(test[predictors])
    combined = pd.DataFrame(dict(actual=test["target"], prediction=preds), index=test.index)
    precision = precision_score(test["target"], preds)
    return combined, precision

# %%
combined, precision = make_predictions(gamelogs_rolling, predictors = new_cols)

# %%
combined = combined.merge(gamelogs_rolling[["Date", "Team", "Opp", "W/L"]], left_index=True, right_index=True)

# %%
class MissingDict(dict):
  __missing__ = lambda self, key: key

map_values = {
    "CRD": "Arizona Cardinals",
    "ATL": "Atlanta Falcons",
    "RAV": "Baltimore Ravens",
    "BUF": "Buffalo Bills",
    "CAR": "Carolina Panthers",
    "CHI": "Chicago Bears",
    "CIN": "Cincinnati Bengals",
    "CLE": "Cleveland Browns",
    "DAL": "Dallas Cowboys",
    "DEN": "Denver Broncos",
    "DET": "Detroit Lions",
    "GNB": "Green Bay Packers",
    "HTX": "Houston Texans",
    "CLT": "Indianapolis Colts",
    "JAX": "Jacksonville Jaguars",
    "KAN": "Kansas City Chiefs",
    "RAI": "Las Vegas Raiders",
    "SDG": "Los Angeles Chargers",
    "RAM": "Los Angeles Rams",
    "MIA": "Miami Dolphins",
    "MIN": "Minnesota Vikings",
    "NWE": "New England Patriots",
    "NOR": "New Orleans Saints",
    "NYG": "New York Giants",
    "NYJ": "New York Jets",
    "PHI": "Philadelphia Eagles",
    "PIT": "Pittsburgh Steelers",
    "SFO": "San Francisco 49ers",
    "SEA": "Seattle Seahawks",
    "TAM": "Tampa Bay Buccaneers",
    "OTI": "Tennessee Titans",
    "WAS": "Washington Football Team"
}

mapping = MissingDict(**map_values)

# %%
mapping["CRD"]
# Out:
# 'Arizona Cardinals'

# %%
combined["new_team"] = combined["Team"].map(mapping)

# %%
merged = combined.merge(combined, left_on=["Date", "new_team"], right_on=["Date", "Opp"])

# %%
merged[(merged["prediction_x"]==1) & (merged["prediction_y"]==0)]["actual_x"].value_counts()
# Out:
# actual_x
# 1    72
# 0    37
# Name: count, dtype: int64

# %%
72/ (72+37)
# Out:
# 0.6605504587155964
